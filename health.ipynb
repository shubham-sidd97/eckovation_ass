# %%
import csv
import pandas as pd
health=pd.read_csv("C:\\Users\\4shub\\Desktop\\summertrainning\\diabetes.csv",error_bad_lines=False)

# %%
health[0:]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
yes=[]
no=[]
for i in range(len(health)):
    if(health['Outcome'][i]==0):
        no.append(health['Pregnancies'][i])
    else:
        yes.append(health['Pregnancies'][i])

# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
plt.hist(yes)
plt.hist(no)
# Out:
# (array([179.,  84.,  48.,  81.,  34.,  20.,  26.,  14.,   4.,  10.]),
#  array([ 0. ,  1.3,  2.6,  3.9,  5.2,  6.5,  7.8,  9.1, 10.4, 11.7, 13. ]),
#  <a list of 10 Patch objects>)

# %%
no
# Out:
# [1,
#  1,
#  5,
#  10,
#  4,
#  10,
#  1,
#  3,
#  8,
#  1,
#  13,
#  5,
#  5,
#  3,
#  6,
#  10,
#  4,
#  11,
#  3,
#  7,
#  7,
#  7,
#  1,
#  2,
#  7,
#  1,
#  1,
#  5,
#  7,
#  1,
#  0,
#  0,
#  0,
#  2,
#  5,
#  2,
#  5,
#  2,
#  1,
#  4,
#  5,
#  4,
#  1,
#  1,
#  7,
#  5,
#  2,
#  3,
#  2,
#  7,
#  0,
#  2,
#  13,
#  2,
#  1,
#  1,
#  4,
#  7,
#  2,
#  6,
#  2,
#  1,
#  6,
#  1,
#  0,
#  1,
#  2,
#  1,
#  1,
#  4,
#  3,
#  1,
#  4,
#  5,
#  4,
#  4,
#  6,
#  2,
#  5,
#  3,
#  1,
#  8,
#  2,
#  2,
#  0,
#  0,
#  0,
#  5,
#  3,
#  5,
#  2,
#  4,
#  0,
#  9,
#  2,
#  5,
#  2,
#  1,
#  4,
#  1,
#  2,
#  1,
#  2,
#  4,
#  7,
#  0,
#  2,
#  3,
#  4,
#  4,
#  3,
#  2,
#  1,
#  2,
#  6,
#  5,
#  6,
#  0,
#  1,
#  5,
#  4,
#  3,
#  9,
#  8,
#  1,
#  0,
#  1,
#  0,
#  2,
#  6,
#  5,
#  1,
#  2,
#  0,
#  7,
#  6,
#  7,
#  7,
#  1,
#  1,
#  0,
#  4,
#  0,
#  1,
#  4,
#  3,
#  0,
#  1,
#  4,
#  2,
#  10,
#  0,
#  9,
#  1,
#  9,
#  2,
#  2,
#  0,
#  3,
#  2,
#  1,
#  3,
#  4,
#  3,
#  5,
# ...

# %%
import pandas as pd
import csv
irs=pd.read_csv("C:\\Users\\4shub\\Desktop\\summertrainning\\Iris.csv",error_bad_lines=False)

# %%
irs[0:]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
list1=[]
list2=[]
list3=[]
list4=[]
blist1=[]
blist2=[]
blist3=[]
blist4=[]
clist1=[]
clist2=[]
clist3=[]
clist4=[]
for i in range(len(irs)):
    if(irs['Species'][i]=='Iris-setosa'):
        list1.append(irs['SepalLengthCm'][i])
        list2.append(irs['SepalWidthCm'][i])
        list3.append(irs['PetalLengthCm'][i])
        list4.append(irs['PetalWidthCm'][i])
    elif(irs['Species'][i]=='Iris-virginica'):
        list1.append(irs['SepalLengthCm'][i])
        list2.append(irs['SepalWidthCm'][i])
        list3.append(irs['PetalLengthCm'][i])
        list4.append(irs['PetalWidthCm'][i])
    else:
        list1.append(irs['SepalLengthCm'][i])
        list2.append(irs['SepalWidthCm'][i])
        list3.append(irs['PetalLengthCm'][i])
        list4.append(irs['PetalWidthCm'][i])

# %%
list1
# Out:
# [5.1,
#  4.9,
#  4.7,
#  4.6,
#  5.0,
#  5.4,
#  4.6,
#  5.0,
#  4.4,
#  4.9,
#  5.4,
#  4.8,
#  4.8,
#  4.3,
#  5.8,
#  5.7,
#  5.4,
#  5.1,
#  5.7,
#  5.1,
#  5.4,
#  5.1,
#  4.6,
#  5.1,
#  4.8,
#  5.0,
#  5.0,
#  5.2,
#  5.2,
#  4.7,
#  4.8,
#  5.4,
#  5.2,
#  5.5,
#  4.9,
#  5.0,
#  5.5,
#  4.9,
#  4.4,
#  5.1,
#  5.0,
#  4.5,
#  4.4,
#  5.0,
#  5.1,
#  4.8,
#  5.1,
#  4.6,
#  5.3,
#  5.0,
#  7.0,
#  6.4,
#  6.9,
#  5.5,
#  6.5,
#  5.7,
#  6.3,
#  4.9,
#  6.6,
#  5.2,
#  5.0,
#  5.9,
#  6.0,
#  6.1,
#  5.6,
#  6.7,
#  5.6,
#  5.8,
#  6.2,
#  5.6,
#  5.9,
#  6.1,
#  6.3,
#  6.1,
#  6.4,
#  6.6,
#  6.8,
#  6.7,
#  6.0,
#  5.7,
#  5.5,
#  5.5,
#  5.8,
#  6.0,
#  5.4,
#  6.0,
#  6.7,
#  6.3,
#  5.6,
#  5.5,
#  5.5,
#  6.1,
#  5.8,
#  5.0,
#  5.6,
#  5.7,
#  5.7,
#  6.2,
#  5.1,
#  5.7,
#  6.3,
#  5.8,
#  7.1,
#  6.3,
#  6.5,
#  7.6,
#  4.9,
#  7.3,
#  6.7,
#  7.2,
#  6.5,
#  6.4,
#  6.8,
#  5.7,
#  5.8,
#  6.4,
#  6.5,
#  7.7,
#  7.7,
#  6.0,
#  6.9,
#  5.6,
#  7.7,
#  6.3,
#  6.7,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.hist(list1)
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(list2)
# Out:
# (array([ 4.,  7., 22., 24., 38., 31.,  9., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(list3)
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(list4)
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <a list of 10 Patch objects>)

# %%
a=[]
b=[]
for i in range(len(irs)):
    if(irs['Species'][i]=='Iris-setosa'):
        a.append(irs['SepalLengthCm'][i])
    elif(irs['Species'][i]=='Iris-virginica'):
        b.append(irs['SepalLengthCm'][i])

# %%
plt.scatter(a,b)
